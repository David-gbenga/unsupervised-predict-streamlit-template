# %% [markdown]
# <h1 style = 'text-align:center;'>  EDKO CONSULTINGS </h1>
# <h6  style = 'text-align:center;'> EDSA Movie Recommendation Notebook for Group 2110ACDS_T14</h6>

# %% [markdown]
# ![image3.JPG](attachment:image3.JPG)

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
#
# <a href=#intro>1. Introduction </a>
#
# <a href=#comet>1(a). Installation of  Comet ML </a>
#
# <a href=#API>1(b). Experiment Created with API key </a>
#
#
# <a href=#pack>2. Importing Packages</a>
#
#
# <a href=#data>3. Loading Data</a>
#
# <a href=#eda>4. Exploratory Data Analysis (EDA)</a>
#
# <a href=#data_p>5. Data Preprocessing & Feature Engineering </a>
#
# <a href=#model>6. Modeling</a>
#
# <a href=#model_p>7. Model Performance & Explanation </a>
#
# <a href=#con>8. Conclusion</a>

# %% [markdown]
# <a id="intro"></a>
#
# # 1. Introduction
# <a href=#cont>Back to Table of Contents</a>
# <hr>
# In today’s technology driven world, recommender systems are socially and economically critical to ensure that individuals can make optimised choices surrounding the content they engage with on a daily basis. One application where this is especially true is movie recommendations; where intelligent algorithms can help viewers find great titles from tens of thousands of options.
#
# With this context, EDSA has consulted EDKO Consultings(2110ACDS_T14) to construct a recommendation algorithm based on content or collaborative filtering, capable of accurately predicting how a user will rate a movie they have not yet viewed, based on their historical preferences.
#
# Providing an accurate and robust solution to this challenge has immense economic potential, with users of the system being personalised recommendations - generating platform affinity for the streaming services which best facilitates their audience's viewing.
#
#
# ### Problem Statements
# <b>Construction of a collaborative filtering recommendation algorithm, which has the capacity to accurately predicting how a user will rate a movie they have not yet viewed using their historical preferences.</b>
#
#
#
# ### Project Road Map
# <hr>
# <li> Analyse the supplied data </li>
# <li> identify potential errors in the data and clean the existing data set </li>
# <li> Matrix Factorization-based Algorithmt</li>
# <li> Creating Handcrafted Features</li>
# <li> Evaluate the performance of the machine learning model</li>
# <li> Highlight key findings .</li>

# %% [markdown]
# <a id="comet"></a>
#
# ## 1(a). Installation to Comet ML
# <a href=#cont>Back to Table of Contents</a>
#
# Comet is a great tool for model versioning and experimentation as it records the parameters and conditions from each of your experiements- allowing you to reproduce your results, or go back to a previous version of your experiment.
#
# Added to this notebook is our api that connects all our team members input to this project

# %%
#This is to install the comet_ml package so we can link our notebook to the online comet project dashboard
# !pip install comet_ml
# Out:
# Requirement already satisfied: comet_ml in c:\programdata\anaconda3\lib\site-packages (3.28.2)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in c:\programdata\anaconda3\lib\site-packages (from comet_ml) (7.352.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from comet_ml) (1.14.0)
# Requirement already satisfied: wrapt>=1.11.2 in c:\programdata\anaconda3\lib\site-packages (from comet_ml) (1.11.2)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in c:\programdata\anaconda3\lib\site-packages (from comet_ml) (3.2.0)
# Requirement already satisfied: everett[ini]>=1.0.1; python_version > "3.5" in c:\programdata\anaconda3\lib\site-packages (from comet_ml) (3.0.0)
# Requirement already satisfied: dulwich!=0.20.33,>=0.20.6; python_version >= "3.0" in c:\programdata\anaconda3\lib\site-packages (from comet_ml) (0.20.34)
# Requirement already satisfied: wurlitzer>=1.0.2 in c:\programdata\anaconda3\lib\site-packages (from comet_ml) (3.0.2)
# Requirement already satisfied: websocket-client>=0.55.0 in c:\programdata\anaconda3\lib\site-packages (from comet_ml) (1.3.1)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from comet_ml) (0.9.1)
# Requirement already satisfied: requests>=2.18.4 in c:\programdata\anaconda3\lib\site-packages (from comet_ml) (2.22.0)
# Requirement already satisfied: semantic-version>=2.8.0 in c:\programdata\anaconda3\lib\site-packages (from comet_ml) (2.9.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (19.3.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (45.2.0.post20200210)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\programdata\anaconda3\lib\site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (1.5.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.15.7)
# Requirement already satisfied: configobj; extra == "ini" in c:\programdata\anaconda3\lib\site-packages (from everett[ini]>=1.0.1; python_version > "3.5"->comet_ml) (5.0.6)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from dulwich!=0.20.33,>=0.20.6; python_version >= "3.0"->comet_ml) (2019.11.28)
# Requirement already satisfied: urllib3>=1.24.1 in c:\programdata\anaconda3\lib\site-packages (from dulwich!=0.20.33,>=0.20.6; python_version >= "3.0"->comet_ml) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.18.4->comet_ml) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.18.4->comet_ml) (2.8)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=3.1.0,>=2.6.0->comet_ml) (2.2.0)

# %% [markdown]
# <a id="API"></a>
#
# ## 1(b). Experiment Created with API key
# <a href=#cont>Back to Table of Contents</a>

# %%
# import comet_ml at the top of your file
from comet_ml import Experiment

# Create an experiment with your api key
experiment = Experiment(
    api_key="JJyrYsOnpzZODYXKuMQOPS60e",
    project_name="movie-recommendation",
    workspace="kachi-k",
)

# %% [markdown]
#  <a id="pack"></a>
# ## 2. Importing Packages
# <a href=#cont>Back to Table of Contents</a>
#
# <b>We imported all the libraries and modules potentially needful for this project.</b>

# %%
import numpy as np
from comet_ml import Experiment
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %% [markdown]
# <a id="data"></a>
#
# ## 3. Loading Data
#
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %%
pd.set_option('max_rows', None) # Display max rows and not a truncated version
pd.set_option('max_columns', None) # Display max columns and not a truncated version
# Use pandas read_csv method to load data
df = pd.read_csv(r'data/train.csv')
dft = pd.read_csv(r'data/test.csv')

# %% [markdown]
# <a id="eda"></a>
# ## 4. Exploratory Data Analysis (EDA)
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# <a id="data_p"></a>
# ## 5. Data Preprocessing & Feature Engineering
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# <a id="model"></a>
# ## 6. Modelling
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# <li> In this section, Different vectorisers and models were used</li>
# <li> Model improvement was also taking into consideration</li>

# %% [markdown]
# <a id="model_p"></a>
# ## 7. Model Performance & Validation
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# <a id="con"></a>
# ## 7. Conclusion
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
