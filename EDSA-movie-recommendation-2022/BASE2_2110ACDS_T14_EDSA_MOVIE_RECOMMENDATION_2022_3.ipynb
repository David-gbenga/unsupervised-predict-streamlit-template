# %% [markdown]
# <h1 style = 'text-align:center;'>  EDKO CONSULTINGS </h1>
# <h6  style = 'text-align:center;'> EDSA Movie Recommendation Notebook for Group 2110ACDS_T14</h6>

# %% [markdown]
# ![image3.JPG](attachment:image3.JPG)

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
#
# <a href=#intro>1. Introduction </a>
#
# <a href=#comet>1(a). Installation of  Comet ML </a>
#
# <a href=#API>1(b). Experiment Created with API key </a>
#
#
# <a href=#pack>2. Importing Packages</a>
#
#
# <a href=#data>3. Loading Data</a>
#
# <a href=#eda>4. Exploratory Data Analysis (EDA)</a>
#
# <a href=#data_p>5. Data Preprocessing & Feature Engineering </a>
#
# <a href=#model>6. Modeling</a>
#
# <a href=#model_p>7. Model Performance & Explanation </a>
#
# <a href=#con>8. Conclusion</a>

# %% [markdown]
# <a id="intro"></a>
#
# # 1. Introduction
# <a href=#cont>Back to Table of Contents</a>
# <hr>
# In today’s technology driven world, recommender systems are socially and economically critical to ensure that individuals can make optimised choices surrounding the content they engage with on a daily basis. One application where this is especially true is movie recommendations; where intelligent algorithms can help viewers find great titles from tens of thousands of options.
#
# With this context, EDSA has consulted EDKO Consultings(2110ACDS_T14) to construct a recommendation algorithm based on content or collaborative filtering, capable of accurately predicting how a user will rate a movie they have not yet viewed, based on their historical preferences.
#
# Providing an accurate and robust solution to this challenge has immense economic potential, with users of the system being personalised recommendations - generating platform affinity for the streaming services which best facilitates their audience's viewing.
#
#
# ### Problem Statements
# <b>Construction of a collaborative filtering recommendation algorithm, which has the capacity to accurately predicting how a user will rate a movie they have not yet viewed using their historical preferences.</b>
#
#
#
# ### Project Road Map
# <hr>
# <li> Analyse the supplied data </li>
# <li> identify potential errors in the data and clean the existing data set </li>
# <li> Matrix Factorization-based Algorithmt</li>
# <li> Creating Handcrafted Features</li>
# <li> Evaluate the performance of the machine learning model</li>
# <li> Highlight key findings .</li>

# %% [markdown]
# <a id="comet"></a>
#
# ## 1(a). Installation to Comet ML
# <a href=#cont>Back to Table of Contents</a>
#
# Comet is a great tool for model versioning and experimentation as it records the parameters and conditions from each of your experiements- allowing you to reproduce your results, or go back to a previous version of your experiment.
#
# Added to this notebook is our api that connects all our team members input to this project

# %%
#This is to install the comet_ml package so we can link our notebook to the online comet project dashboard
# !pip install comet_ml

# %% [markdown]
# <a id="API"></a>
#
# ## 1(b). Experiment Created with API key
# <a href=#cont>Back to Table of Contents</a>

# %%
# import comet_ml at the top of your file
from comet_ml import Experiment

# Create an experiment with your api key
experiment = Experiment(
    api_key="JJyrYsOnpzZODYXKuMQOPS60e",
    project_name="movie-recommendation",
    workspace="kachi-k",
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/kachi-k/movie-recommendation/65793f38f22e4e24a5627a3d9e91d0fd

# %%
# !pip install surprise

# %% [markdown]
#  <a id="pack"></a>
# ## 2. Importing Packages
# <a href=#cont>Back to Table of Contents</a>
#
# <b>We imported all the libraries and modules potentially needful for this project.</b>

# %%
from time import time
import numpy as np
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection, preprocessing)
from matplotlib import offsetbox
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
from wordcloud import WordCloud
# Entity featurization and similarity computation
from sklearn.metrics.pairwise import cosine_similarity 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
# Libraries used during sorting procedures.
import operator # <-- Convienient item retrieval during iteration 
import heapq # <-- Efficient sorting of large lists

# Imported for our sanity
import warnings
warnings.filterwarnings('ignore')
sns.set(style='whitegrid', palette='muted',
        rc={'figure.figsize': (15,10)})
import pandas as pd
import cufflinks as cf
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import collections
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error as MSE
from sklearn.ensemble import  RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
import xgboost
from surprise.model_selection import cross_validate
from xgboost import XGBRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from surprise import Reader, Dataset, SVD
from sklearn.model_selection import train_test_split
from surprise.model_selection import train_test_split
from sklearn.model_selection import cross_validate
reader = Reader()
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
import os
from surprise.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set(style='whitegrid', palette='muted',
        rc={'figure.figsize': (15,10)})

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <a id="data"></a>
#
# ## 3. Loading Data
#
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %%
# !gdown --id 19_nTeSNZCJCRUttglAcZXbREg41hGdzC
# !gdown --id 1NF76NgbbmYtzaZesCKqR18WDga4k39js
# !gdown --id 1ZCLAEWyGjURSe36prBDM8ppt5vDGait0
# !gdown --id 1c3W3AGNexRaK7fZZN0ICuf9ljLfUy_h0
# !gdown --id 1y7OpOfNCcwRDJrSZvufyN2t1S8wwWbYw
# !gdown --id 1QgmgplqGKMMlK1Ik7BFdQuz8SnrBdy1h
# !gdown --id 1GfaefY6duSMZDZ8lA0Zry2xe-k-70UPL
# !gdown --id 1IBALHeBFmlfLag887LhDQx8f-riAct_r
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=19_nTeSNZCJCRUttglAcZXbREg41hGdzC
# To: /content/train.csv
# 100% 261M/261M [00:01<00:00, 240MB/s]
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1NF76NgbbmYtzaZesCKqR18WDga4k39js
# To: /content/test.csv
# 100% 56.8M/56.8M [00:00<00:00, 233MB/s]
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# ...

# %%
# This code is to store the datasets into dataframes
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
genome_scores = pd.read_csv('genome_scores.csv')
genome_tags = pd.read_csv('genome_tags.csv')
imdb_data = pd.read_csv('imdb_data.csv')
links = pd.read_csv('links.csv')
movies = pd.read_csv('movies.csv')
tags = pd.read_csv('tags.csv')

# %% [markdown]
# <a id="eda"></a>
# ## 4. Exploratory Data Analysis (EDA)
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# We will look at each data set and plot all the necessary visuals to help us understand what is in the data and how can it be useful to us in designing a movie recommender system.

# %% [markdown]
# ###Train Data

# %%
# The info() method prints information about the DataFrame. 
#The information contains the number of columns, column labels, 
#column data types, memory usage, range index, and the number of cells in each 
#column (non-null values). Note: the info() method actually prints the info.
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000038 entries, 0 to 10000037
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 305.2 MB

# %%
df_train.head()
# Out:
#    userId  movieId  rating   timestamp
# 0    5163    57669     4.0  1518349992
# 1  106343        5     4.5  1206238739
# 2  146790     5459     5.0  1076215539
# 3  106362    32296     2.0  1423042565
# 4    9041      366     3.0   833375837

# %%
print (f'Number of movieid in dataset: {df_train.shape[0]}')
# Out:
# Number of movieid in dataset: 10000038

# %%
with sns.axes_style('white'):
    g = sns.factorplot("rating", data=df_train, aspect=2.0,kind='count')
    g.set_ylabels("Total number of ratings")
print (f'Average rating in dataset: {np.mean(df_train["rating"])}')
# Out:
# Average rating in dataset: 3.5333951730983424

# %%
df_train.corr()
# Out:
#              userId   movieId    rating  timestamp
# userId     1.000000 -0.004270  0.002202  -0.001347
# movieId   -0.004270  1.000000 -0.008940   0.520786
# rating     0.002202 -0.008940  1.000000   0.010301
# timestamp -0.001347  0.520786  0.010301   1.000000

# %%
plt.figure(figsize=(8, 10))
heatmap = sns.heatmap(df_train.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':40}, pad=35);

# %%
corrmat = df_train.corr()
k = 4 #number of variables for heatmap
cols = corrmat.nlargest(k, 'rating')['rating'].index
cm = np.corrcoef(df_train[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# ###Genome Score and Genome Tags

# %% [markdown]
# We look at these two together as they are somewhat related.
#
# A genome tag is a single characteristic exhibited by a movie (for example, atmospheric, thought-provoking, realistic etc.). Each genome tag score reflects the relevance of a tag to a movie on a scale of 0 to 1.

# %%
genome_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15584448 entries, 0 to 15584447
# Data columns (total 3 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   movieId    int64
#  1   tagId      int64
#  2   relevance  float64
# dtypes: float64(1), int64(2)
# memory usage: 356.7 MB

# %%
genome_tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1128 entries, 0 to 1127
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tagId   1128 non-null   int64
#  1   tag     1128 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 17.8+ KB

# %%
genome_scores.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02875
# 1        1      2    0.02375
# 2        1      3    0.06250
# 3        1      4    0.07575
# 4        1      5    0.14075

# %%
genome_tags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %% [markdown]
# Let's join these two and see what we are able to get from them.

# %%
genome_tags_scores = genome_scores.merge(genome_tags, on='tagId', how='inner')

# %%
genome_tags_scores.head()
# Out:
#    movieId  tagId  relevance  tag
# 0        1      1    0.02875  007
# 1        2      1    0.04125  007
# 2        3      1    0.04675  007
# 3        4      1    0.03425  007
# 4        5      1    0.04300  007

# %% [markdown]
# Let's see which are the most popular tags in movies.

# %%
data = genome_tags_scores['tag'].value_counts().to_dict()
wc = WordCloud().generate_from_frequencies(data)

plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# This shows us the most commonly used tags. The most popular movie tag here being 007. This could mean that a movie makes reference to the James Bond movie series or probably having a similar theme to the movie series.
# This is definitely influential to the rating a movie receives or the chances a movie gets to be watched by a user. We will verify this at a later stage.

# %% [markdown]
# ###Imdb Data and Links[link text]
#
# These two are also related. We will explore them together.

# %%
imdb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movieId        27278 non-null  int64
#  1   title_cast     17210 non-null  object
#  2   director       17404 non-null  object
#  3   runtime        15189 non-null  float64
#  4   budget         7906 non-null   object
#  5   plot_keywords  16200 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.2+ MB

# %%
links.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62423 entries, 0 to 62422
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  62423 non-null  int64
#  1   imdbId   62423 non-null  int64
#  2   tmdbId   62316 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 1.4 MB

# %%
imdb_data.isnull().sum()
# Out:
# movieId              0
# title_cast       10068
# director          9874
# runtime          12089
# budget           19372
# plot_keywords    11078
# dtype: int64

# %% [markdown]
# That's a lot of null entries. We are going to have to do something about that later.

# %%
links.isnull().sum()
# Out:
# movieId      0
# imdbId       0
# tmdbId     107
# dtype: int64

# %% [markdown]
# It is important to look out for null values in a given dataset. Null values are common in real life data because of many reasons for example: failure to make an entry, a given value is just not available and such like things that happen in real life handling of data.
#
# Let's visualize these null values to help us determine their magnitude and determine the best way to deal with them.

# %%
imdb_counts = imdb_data.isnull().sum()
links_counts = links.isnull().sum()

plt.bar(imdb_counts.index,
        imdb_counts.values.reshape(len(imdb_counts), ),
        color='crimson')
plt.xlabel('column_name')
plt.ylabel('count')
plt.title('Null value count in imdb_data')
plt.show()

# %%
plt.bar(links_counts.index,
        links_counts.values.reshape(len(links_counts), ),
        color='crimson')
plt.xlabel('column_name')
plt.ylabel('count')
plt.title('Null value count in imdb_data')
plt.show()

# %% [markdown]
# The links dataset contains 107 null values in the tmdbId column.
#
# The tmdb_data dataset contains alot of null values in 5 out of 6 columns. The column with the largest number of null values is the budget column.
#
# There are various ways of dealing with null values. These include:
# 1. Deleting Rows with missing values
# 2. Impute missing values for continuous variable
# 3. Impute missing values for categorical variable
# 4. Other Imputation Methods
# 5. Using Algorithms that support missing values
# 6. Prediction of missing values
# 7. Imputation using Deep Learning Library — Datawig

# %%
imdb_data.head()
# Out:
#    movieId                                         title_cast  \
# 0        1  Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        2  Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        3  Walter Matthau|Jack Lemmon|Sophia Loren|Ann-Ma...
# 3        4  Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        5  Steve Martin|Diane Keaton|Martin Short|Kimberl...
#
#               director  runtime       budget  \
# 0        John Lasseter     81.0  $30,000,000
# 1   Jonathan Hensleigh    104.0  $65,000,000
# 2  Mark Steven Johnson    101.0  $25,000,000
# 3       Terry McMillan    124.0  $16,000,000
# 4       Albert Hackett    106.0  $30,000,000
#
#                                        plot_keywords
# 0                   toy|rivalry|cowboy|cgi animation
# 1                   board game|adventurer|fight|game
# 2                         boat|lake|neighbor|rivalry
# 3  black american|husband wife relationship|betra...
# ...

# %% [markdown]
# Movie enthusiasts would definitely be interested in a movie based on who directed. This also determines the ratings a movie would receive. Don't take my word for it, we'll confirm that in a bit.

# %%
movies_df=pd.merge(df_train, movies,on='movieId',how='inner')
movies_df.head()
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0    5163    57669     4.0  1518349992  In Bruges (2008)
# 1   87388    57669     3.5  1237455297  In Bruges (2008)
# 2  137050    57669     4.0  1425631854  In Bruges (2008)
# 3  120490    57669     4.5  1408228517  In Bruges (2008)
# 4   50616    57669     4.5  1446941640  In Bruges (2008)
#
#                         genres
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
# 2  Comedy|Crime|Drama|Thriller
# 3  Comedy|Crime|Drama|Thriller
# 4  Comedy|Crime|Drama|Thriller

# %%
movies_ratings_df = pd.merge(movies_df,imdb_data,on='movieId',how='left')
movies_ratings_df = movies_ratings_df.drop(['timestamp'], axis = 1)
movies_ratings_df.head()
# Out:
#    userId  movieId  rating             title                       genres  \
# 0    5163    57669     4.0  In Bruges (2008)  Comedy|Crime|Drama|Thriller
# 1   87388    57669     3.5  In Bruges (2008)  Comedy|Crime|Drama|Thriller
# 2  137050    57669     4.0  In Bruges (2008)  Comedy|Crime|Drama|Thriller
# 3  120490    57669     4.5  In Bruges (2008)  Comedy|Crime|Drama|Thriller
# 4   50616    57669     4.5  In Bruges (2008)  Comedy|Crime|Drama|Thriller
#
#                                           title_cast         director  \
# 0  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 1  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 2  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 3  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 4  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
#
#    runtime       budget              plot_keywords
# ...

# %%
def plot_by_ratings(df,column, n):
    plt.figure(figsize=(14,7))
    data = df[str(column)].value_counts().head(n)
    ax = sns.barplot(x = data.index, y = data, order= data.index, palette='rocket', edgecolor="black")
    for p in ax.patches:
        ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()), fontsize=11, ha='center', va='bottom')
    plt.title(f'Top {n} {column.title()} by Number of Ratings', fontsize=14)
    plt.xlabel(column.title())
    plt.ylabel('Number of Ratings')
    plt.xticks(rotation=90)
    plt.show()

# %%
plot_by_ratings(movies_ratings_df,'title',15)

# %% [markdown]
# Here we see the most rated movies. They are not necessarily top_rated but the ones rated by the most users. From the top 15 we see that they are all 20 years and above old with the oldest being 45 years old.
#
# Could it be they have received more ratings because they have been watched for longer?

# %%
plot_by_ratings(movies_ratings_df,'director',15)

# %% [markdown]
# Quentin Tarantino is an American filmmaker, actor, film critic and author. His films are characterized by frequent references to popular culture and film history, nonlinear storylines, dark humor, stylized violence, extended dialogue, pervasive use of profanity, cameos and ensemble casts.
# He has been nominated for 88 movie awards and won 35 of those. His most popular works include : Pulp Fiction, Django Unchained, Inglourious Bastards and Once Upon a Time in Holywood to name but a few.
#
# We see here the other popular names like James Cameron, JRR Tolkien and the likes.
#
# Quentin is an obvious outlier here. Pulp Fiction one of his films appears in the most rated films. This suggests that a movies' directorship could influence how it is rated.

# %% [markdown]
# We proceed to merge all these data sets and move onto pre-processing.

# %%
working_df = pd.merge(movies_ratings_df,genome_tags_scores,on='movieId',how='inner')

# %% [markdown]
# <a id="data_p"></a>
# ## 5. Data Preprocessing & Feature Engineering
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %%
#Deleting the timestamp column
df_train_X = df.drop(['timestamp'],axis=1)
df_train_X.head()
# Out:
#    userId  movieId  rating
# 0    5163    57669     4.0
# 1  106343        5     4.5
# 2  146790     5459     5.0
# 3  106362    32296     2.0
# 4    9041      366     3.0

# %%
#Filtering strategy applied to reduce the dataset due to lack of cmputing power: take records with greater than rating ()
df_use = df_train_X[df_train_X.rating>4]
df_use.shape[0]
# Out:
# 2325746

# %%
#Filtering strategy applied to reduce the dataset due to lack of cmputing power: take users who have more than () ratings 
new_df=df_train_X.groupby("movieId").filter(lambda x:x['rating'].count() >=3000)
new_df.shape[0]
# Out:
# 5546995

# %%
#Pearson methon was used to train the data and predict using a all columns dataset

# %%
#Reading the dataset
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df_use,reader)

# %%
#Splitting the dataset
trainset, testset = train_test_split(data, test_size=0.2,random_state=10)

# %%
# Use user_based true/false to switch between user-based or item-based collaborative filtering
algo = KNNWithMeans(k=3, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
# run the trained model against the testset
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid=134931, iid=1674, r_ui=5.0, est=4.995028069378161, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid=91007, iid=2333, r_ui=5.0, est=4.9923810687907295, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=29131, iid=1197, r_ui=4.5, est=4.53899309627108, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=61426, iid=593, r_ui=4.5, est=4.854412769510688, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=67329, iid=593, r_ui=5.0, est=4.810799066535669, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=43217, iid=70286, r_ui=4.5, est=4.480807759587636, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=7540, iid=838, r_ui=4.5, est=4.742077644477963, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=2390, iid=134853, r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
# ...

# %%
# get RMSE
print("Item-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 0.2261
# 0.22613302595030665

# %% [markdown]
# <a id="model"></a>
# ## 6. Modelling
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# <li> In this section, Different vectorisers and models were used</li>
# <li> Model improvement was also taking into consideration</li>

# %%
#surprise.model_selection.validation.cross_validate(algo, data, measures=[u'rmse', u'mae'], cv=None, return_train_measures=False, n_jobs=1, pre_dispatch=u'2*n_jobs', verbose=False)

# %%
# Create a Surprise Dataset : In order to train recommender systems with Surprise, I inserted my newly filtered  Dataset object.
from surprise import Dataset
from surprise import Reader
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(new_df[['userId', 'movieId', 'rating']], reader)

# %%
#In the code below, I cross-validated an SVD model using three-fold cross-validation
from surprise import SVD
from surprise.model_selection import cross_validate
svd = SVD(verbose=True, n_epochs=10)
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.8682  0.8675  0.8670  0.8675  0.0005
# MAE (testset)     0.6609  0.6601  0.6597  0.6602  0.0005
# Fit time          115.56  120.55  122.09  119.40  2.79
# Test time         27.05   26.08   25.57   26.23   0.62
# ...

# %%
#I trained the model on the entire dataset using the fit method
trainset = data.build_full_trainset()
svd.fit(trainset)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9

# %%
# Out:
# surprise.trainset.Trainset

# %%
# this is a sample prediction for user_id 9041 and movie_id 366
svd.predict(uid=9041, iid=366)[3]
# Out:
# 4.206124648045075

# %%
def predict_svd(uid, mvid):
  svd_pred = svd.predict(uid=uid, iid=mvid)
  return round(svd_pred[3],1)

# %%
df_test2 =dft

# %%
df_test2['rating'] = df_test2.apply(lambda row: predict_svd(row['userId'], row['movieId']), axis=1)

# %%
df_test2.head()
# Out:
#    userId  movieId  rating
# 0       1     2011     3.7
# 1       1     4144     3.8
# 2       1     5767     3.8
# 3       1     6711     3.9
# 4       1     7318     3.8

# %%
! gdown --id 1418o04wlD3kX7tuynX3qWjl8WY4yEkw9
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1418o04wlD3kX7tuynX3qWjl8WY4yEkw9
# To: /content/sample_submission.csv
# 100% 76.8M/76.8M [00:00<00:00, 153MB/s]

# %%
df_sub = pd.read_csv('sample_submission.csv')

# %%
kaggle_file2 =df_sub[['Id']]

# %%
kaggle_file2['rating']= df_test2['rating']

# %%
kaggle_file2.to_csv('draft3.csv', index = None)

# %% [markdown]
# <a id="model_p"></a>
# ## 7. Model Performance & Validation
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# <a id="con"></a>
# ## 7. Conclusion
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
